# %% [markdown]
# # Day 3 - Python Exercises: Cryptography Concepts
# # Cyber Squad - U.S. Cyber Range edition
# # Run each cell with Shift + Enter. Fill in the blanks marked ___.

# %%
# Exercise 1: Caesar cipher brute force
ciphertext = "KHOOR"
for shift in range(1, ___):  # try all shifts from 1 to 25
    decoded = ""
    for c in ciphertext:
        if c.isalpha():
            decoded += chr((___ - shift - 65) % 26 + 65)  # fill: ord(c)
        else:
            decoded += c
    print(f"shift {shift}: {decoded}")

# %%
# Exercise 2: Base64 encode and decode
import base64
msg = b"Hello, Cyber Squad!"
encoded = base64.b64encode(___)   # encode the message
print("encoded:", encoded)
decoded = base64.b64decode(___)   # decode it back
print("decoded:", decoded)

# %%
# Exercise 3: XOR cipher
key = 42
plaintext = b"Secret"
xored = bytes(b ^ ___ for b in plaintext)  # XOR each byte with key
print("XORed:", xored)
back = bytes(b ^ ___ for b in xored)       # XOR again to recover
print("recovered:", back)

# %%
# Exercise 4: Avalanche effect with SHA-256
import hashlib
h1 = hashlib.sha256(b"password").hexdigest()
h2 = hashlib.sha256(b"Password").hexdigest()  # capital P
print("password hash:", h1)
print("Password hash:", h2)
